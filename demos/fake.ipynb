# %%
from beautylogger import BeautyLogger
import numpy as np
# %matplotlib inline

# %%
logger = BeautyLogger(plots=[('plot', 'metrics')])

for i in range(100):
    for j in range(10):
        logger.log_step(metrics=np.random.randn())
        logger.log_step('test', metrics=np.random.randn())
    logger.log_epoch()
    logger.plot()
